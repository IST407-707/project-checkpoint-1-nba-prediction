# %%
### Head

import pandas as pd
import numpy as np
from os import listdir as ls
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
import warnings
from tensorflow.keras.losses import categorical_crossentropy
from sklearn.metrics import confusion_matrix
# Out:
# 2024-04-13 20:29:55.010931: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-13 20:29:55.371861: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-13 20:29:55.645511: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-13 20:29:56.854144: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
ad_stats_14 = pd.read_csv("/workspaces/project-checkpoint-1-nba-prediction/dev/advanced_stats_14_15.csv")
ad_stats_15 = pd.read_csv("/workspaces/project-checkpoint-1-nba-prediction/dev/advanced_stats_15_16.csv")
ad_stats_14 = ad_stats_14.rename(columns= {"BPM▼" : "BPM"})
ad_stats_15 = ad_stats_15.rename(columns= {"BPM▼" : "BPM"})
ad_stats_14["season"] = "2014-2015"
ad_stats_15["season"] = "2015-2016"

# %%
test = pd.concat([ad_stats_14, ad_stats_15])

# %%
len(ad_stats_14)
# Out:
# 186

# %%
#create a dictionary with season team and per list 
#seasons_bpm = pd.read_csv('seasons_per_s.csv')
teams = test["Tm"].unique()
#season,team_id,player_dir,per

def get_top_n_pers(seasons_pers, n): # can adjust to get pers of past seasonm on the new seasons roster
    roster_pers = {}
    for season in seasons_pers['season'].unique():
        subset = seasons_pers[seasons_pers['season'] == season]
        roster_pers[season] = {}
        for team in teams:
            team_subset = subset[subset['Tm'] ==  team]
            team_subset = team_subset.sort_values(by='BPM', ascending=False)
            roster_pers[season][team] = np.float16(team_subset['BPM'].iloc[:n]).flatten()
    return roster_pers

rosters = get_top_n_pers(test, 8)  # rosters[season][team]

# %%
pd.DataFrame(rosters)
# Out:
#                                         2014-2015  \
# GSW                [9.9, 4.4, 3.5, 2.4, 0.9, 0.1]
# NOP            [8.9, 1.2, -0.3, -1.0, -1.2, -2.5]
# HOU                    [8.8, 1.0, 0.5, 0.1, -0.5]
# OKC                         [8.1, 1.8, 0.9, -1.3]
# LAC               [8.0, 4.0, 2.9, 1.3, 0.7, -0.3]
# CLE                         [7.1, 4.1, 2.7, -1.2]
# SAS              [5.9, 5.1, 4.6, 1.7, -0.4, -1.3]
# MEM                    [5.1, 2.8, 1.6, 1.3, -0.5]
# POR               [4.7, 3.1, 2.9, 2.1, 0.1, -1.8]
# CHI   [4.6, 3.5, 2.3, 2.1, 0.0, -0.4, -0.6, -0.8]
# SAC                   [4.3, 2.7, 2.1, -2.2, -2.8]
# UTA       [4.2, 4.0, 2.5, -0.2, -1.2, -1.4, -4.3]
# ATL               [4.1, 3.4, 2.9, 2.8, 1.7, -1.3]
# WAS              [3.6, 1.5, 1.5, 0.1, -0.8, -0.8]
# TOT     [3.2, 1.6, 1.1, 0.8, 0.7, 0.7, 0.5, -0.1]
# TOR  [3.0, 2.6, 2.5, 0.5, -0.1, -0.9, -1.0, -1.4]
# DAL                    [2.6, 2.2, 1.6, 1.4, -0.1]
# CHO             [2.3, 1.6, 0.0, -0.5, -1.4, -4.5]
# DEN                             [2.2, -0.1, -0.6]
# PHO                   [2.1, 0.4, 0.1, -0.3, -1.8]
# MIA                         [2.1, 1.3, 0.0, -2.5]
# DET                       [2.0, -0.1, -1.7, -1.7]
# MIL              [1.6, 0.6, 0.4, 0.0, -0.6, -2.1]
# IND             [1.6, 0.9, 0.3, -0.3, -1.2, -1.5]
# LAL           [1.5, -0.4, -1.7, -1.9, -2.2, -2.3]
# BRK       [1.2, 0.2, 0.1, -0.1, -1.1, -1.5, -1.7]
# BOS             [1.1, 0.9, 0.0, -0.5, -1.0, -2.2]
# ORL            [0.9, 0.5, -0.4, -1.2, -1.5, -1.8]
# PHI                       [0.7, -0.3, -1.8, -2.8]
# MIN                             [0.2, -2.4, -4.6]
# NYK                            [-2.8, -2.8, -3.8]
#
#                                             2015-2016
# GSW                  [11.9, 5.5, 1.8, 1.1, 0.3, -1.3]
# NOP                      [3.9, 2.1, -0.2, -2.6, -2.8]
# HOU                        [6.6, 0.4, 0.2, 0.1, -2.9]
# OKC             [9.9, 7.8, 1.2, 0.5, 0.2, -0.6, -2.8]
# LAC                       [7.9, 2.8, 2.2, -0.2, -1.4]
# CLE                   [9.0, 3.3, 2.3, 0.5, 0.2, -1.2]
# SAS                    [9.1, 3.0, 2.3, 1.5, 1.1, 0.4]
# MEM                      [3.0, 1.7, -0.3, -0.9, -1.0]
# POR                   [4.4, 1.9, 1.5, 1.3, 0.1, -1.0]
# CHI                  [4.9, 4.4, 1.5, 0.0, -2.5, -2.9]
# SAC                  [3.3, 1.0, 0.1, 0.1, -0.3, -3.8]
# UTA                         [3.3, 2.6, 2.2, 0.7, 0.0]
# ATL             [4.2, 3.8, 1.3, 0.8, 0.3, -0.8, -1.0]
# WAS            [3.5, 1.1, 0.6, 0.3, -0.1, -0.3, -2.1]
# TOT   [1.5, -0.2, -1.0, -1.6, -1.8, -1.9, -2.4, -3.3]
# TOR      [5.8, 2.5, 1.7, 0.3, -0.1, -0.2, -1.1, -1.2]
# DAL           [2.5, 2.0, 0.0, -0.2, -0.3, -1.0, -1.6]
# CHO                 [4.0, 2.7, 1.2, -0.1, -0.8, -0.9]
# DEN            [3.9, 2.7, 0.8, 0.3, -0.8, -0.9, -4.2]
# PHO               [1.3, -0.6, -1.1, -1.2, -2.8, -4.3]
# MIA            [4.1, 4.0, 1.9, 0.8, -0.4, -2.6, -3.1]
# DET                      [2.7, 1.1, -0.2, -0.3, -3.3]
# MIL                 [2.1, 2.1, 0.6, -0.7, -0.8, -2.0]
# IND                  [4.9, 0.9, 0.7, 0.1, -0.7, -1.6]
# LAL               [1.3, -1.6, -1.6, -2.3, -3.2, -3.2]
# BRK                      [1.3, 0.0, -2.0, -2.8, -3.5]
# BOS             [4.3, 2.2, 1.2, 0.6, 0.0, -0.1, -1.0]
# ORL                       [1.9, 1.7, 1.0, -0.3, -1.2]
# PHI  [-0.2, -0.9, -1.2, -1.7, -2.3, -2.4, -3.4, -3.8]
# MIN                 [2.2, 1.8, 0.8, -1.3, -1.5, -2.5]
# NYK                [3.3, 0.9, -0.2, -0.6, -1.0, -2.9]
